# %% [markdown]
# # Compute embedding of image datasets: Evol data & Reference data

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("/n/home12/binxuwang/Github/Neuro-ActMax-GAN-comparison")
import torch
import numpy as np
import os
import glob
from os.path import join
from tqdm import tqdm, trange
from PIL import Image
import pickle as pkl
import matplotlib.pyplot as plt
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader, TensorDataset
from core.utils.dataset_utils import ImagePathDataset, normalizer, denormalizer, ImageDataset_filter
from core.utils.plot_utils import saveallforms
from neuro_data_analysis.neural_data_lib import load_img_resp_pairs_multiwindow, load_neural_data # load_img_resp_pairs_multiwindow
# from CorrFeatTsr_lib import Corr_Feat_Machine, visualize_cctsr, loadimg_preprocess
# from core.utils.layer_hook_utils import featureFetcher_module
# from core.utils.CNN_scorers import TorchScorer, load_featnet
# os.environ["PYTORCH_ENABLE_MPS_FALLBACK"] = "1"
# Out:
# Warning: skimage.transform is not available. Will use scipy.misc.imresize instead.
# Warning: skimage.transform is not available. Will use scipy.misc.imresize instead.

# %%
from torchvision.datasets import ImageFolder
def embed_imgs(imgfps, embed_model, batch_size=100, size=224, device="cuda", num_workers=8):
    dataset = ImagePathDataset(imgfps, transform=transforms.Compose([
        transforms.Resize((size, size)),
        transforms.ToTensor(),
        normalizer,
    ]))
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers)
    embed_model = embed_model.to(device)
    embed_model.eval()
    embeddings = []
    for batch, _ in tqdm(dataloader):
        with torch.no_grad():
            embed_vec = embed_model(batch.to(device))
        embeddings.append(embed_vec)
    embeddings = torch.cat(embeddings, dim=0).detach().cpu()
    return embeddings, dataset


def embed_dataset(dataset, embed_model, batch_size=100, size=224, device="cuda", num_workers=8):
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers)
    embed_model = embed_model.to(device)
    embed_model.eval()
    embeddings = []
    for batch in tqdm(dataloader):
        if isinstance(batch, tuple) or isinstance(dataset, ImageFolder):
            batch = batch[0]
        assert batch.shape[2] == batch.shape[3] == size
        with torch.no_grad():
            embed_vec = embed_model(batch.to(device))
        embeddings.append(embed_vec.detach().cpu())
    embeddings = torch.cat(embeddings, dim=0)
    return embeddings

# %%
embed_model = torch.hub.load('facebookresearch/dinov2', 'dinov2_vitb14')
# Out:
# Using cache found in /n/holylabs/LABS/kempner_fellows/Users/binxuwang/torch_cache/hub/facebookresearch_dinov2_main
# /n/holylabs/LABS/kempner_fellows/Users/binxuwang/torch_cache/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /n/holylabs/LABS/kempner_fellows/Users/binxuwang/torch_cache/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /n/holylabs/LABS/kempner_fellows/Users/binxuwang/torch_cache/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")

# %%
import platform
from core.utils.dataset_utils import ImageDataset_filter
from core.utils.dataset_utils import create_imagenet_valid_dataset

if platform.system() == "Windows":
    stim_rootdir = "S:"
    device = "cuda"
elif platform.system() == "Darwin":
    stim_rootdir = "/Users/binxuwang/Network_mapping"
    device = "mps"
elif platform.system() == "Linux":
    stim_rootdir = "/n/holylabs/LABS/kempner_fellows/Users/binxuwang/Datasets"
    stim_rootdir = "/n/holyscratch01/kempner_fellows/Users/binxuwang/Datasets"
    device = "cuda"

GANimgroot = join(stim_rootdir, "GAN_sample_fid")
os.listdir(GANimgroot)

# %%
# load the neural data
BFEStats_merge, BFEStats = load_neural_data()
rsp_wdws = [range(50, 200), range(0, 50), range(50, 100), range(100, 150), range(150, 200)]

# %%
BFEStats[1]["meta"]

# %% [markdown]
# ## Compute DINO Embeddings

# %% [markdown]
# ### BigGAN Evolution image embedding

# %%
embed_root = "/n/holylabs/LABS/kempner_fellows/Users/binxuwang/Projects/BigGAN_img_embedding"
embed_dir = join(embed_root, "dinov2_vitb14")
os.makedirs(embed_dir, exist_ok=True)

# %%
num_workers = 8
for Expi in trange(63, 1 + 190):
    if BFEStats[Expi-1]["evol"] is None:
        print(f"Exp {Expi} is None")
        continue
    try:
        imgfps0, resp_mat0, gen_vec0 = load_img_resp_pairs_multiwindow(BFEStats, Expi,
                            "Evol", thread=0, stimdrive=stim_rootdir,
                            output_fmt="vec", rsp_wdws=rsp_wdws)
        imgfps1, resp_mat1, gen_vec1 = load_img_resp_pairs_multiwindow(BFEStats, Expi,
                            "Evol", thread=1, stimdrive=stim_rootdir,
                            output_fmt="vec", rsp_wdws=rsp_wdws)
    except IndexError or FileNotFoundError:
        print(f"File missing for Exp {Expi}")
        continue
    if len(imgfps0) == 0 or len(imgfps1) == 0:
        continue
    embeddings0, dataset0 = embed_imgs(imgfps0, embed_model, batch_size=100, size=224, device=device, num_workers=num_workers)
    embeddings1, dataset1 = embed_imgs(imgfps1, embed_model, batch_size=100, size=224, device=device, num_workers=num_workers)
    embed_act_dict = {
        "embeddings0": embeddings0,
        "embeddings1": embeddings1,
        "imgfps0": imgfps0,
        "imgfps1": imgfps1,
        "resp_mat0": resp_mat0,
        "resp_mat1": resp_mat1,
        "gen_vec0": gen_vec0,
        "gen_vec1": gen_vec1,
    }
    pkl.dump(embed_act_dict, open(join(embed_dir, f"Exp{Expi:03d}_embed_act_data.pkl"), "wb"))
    print(f"Exp {Expi} done. saved to {embed_dir}")

# %% [markdown]
# ### ImageNet Embedding

# %%
rootdir = r"/n/holylabs/LABS/kempner_fellows/Users/binxuwang/Datasets/imagenet-valid"
INdataset = create_imagenet_valid_dataset(imgpix=224,rootdir=rootdir)
dataloaders = DataLoader(INdataset, batch_size=256, shuffle=False, num_workers=8)

# %%
# show the image
img, score = INdataset[1]
plt.imshow(denormalizer(img).permute(1, 2, 0))
plt.title(score)

# %%
embed_model.cuda().eval()
embedding_col = []
for batch, _ in tqdm(dataloaders):
    with torch.no_grad():
        embed_vec = embed_model(batch.cuda())
    embedding_col.append(embed_vec.detach().cpu())

embedding_mat = torch.cat(embedding_col, dim=0)
pkl.dump(embedding_mat, open(join(embed_dir, "imagenet_valid_embedding.pkl"), "wb"))

# %% [markdown]
# ### GAN reference image embedding

# %%
GANimgroot = join(stim_rootdir, "GAN_sample_fid")
os.listdir(GANimgroot)
# Out:
# ['BigGAN_trunc07',
#  'resnet50_linf8_gradevol_avgpool',
#  'DeePSim_4std',
#  'resnet50_linf8_gradevol_layer3',
#  'resnet50_linf8_gradevol',
#  'pink_noise',
#  'BigGAN_1000cls_std07_invert',
#  'yolo_summary',
#  'yolo_objconf_summary',
#  'BigGAN_std_008',
#  'resnet50_linf8_gradevol_layer4']

# %%
default_tfm = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    normalizer,
])

# %%
imgroot = join(GANimgroot, "BigGAN_1000cls_std07_invert")
FCinvertdataset = ImageDataset_filter(imgroot, glob_pattern="FC_invert*", 
                            transform=default_tfm)
BGorigdataset = ImageDataset_filter(imgroot, glob_pattern="BG*", 
                            transform=default_tfm)
BGBlurdataset = ImageDataset_filter(imgroot, glob_pattern="BG*",
                            transform=transforms.Compose([
                               transforms.ToTensor(), 
                               transforms.GaussianBlur([15, 15], sigma=9),
                               transforms.Resize((224, 224)),
                               normalizer,]))
print(len(FCinvertdataset), len(BGorigdataset), len(BGBlurdataset))

imageset_str = "DeePSim_4std"
FCdataset = ImageDataset_filter(join(GANimgroot, "DeePSim_4std"), 
                    glob_pattern="sample*", transform=default_tfm)
print(imageset_str, len(FCdataset))
imageset_str = "BigGAN_trunc07"
BGdataset = ImageDataset_filter(join(GANimgroot, "BigGAN_trunc07"), 
                    glob_pattern="sample*", transform=default_tfm)
print(imageset_str, len(BGdataset))
imageset_str = "BigGAN_std_008"
BGRNDdataset = ImageDataset_filter(join(GANimgroot, "BigGAN_std_008"), 
                    glob_pattern="sample*", transform=default_tfm)
print(imageset_str, len(BGRNDdataset))

imageset_str = "resnet50_linf8_gradevol"
gradevoldataset_fc = ImageDataset_filter(join(GANimgroot, "resnet50_linf8_gradevol"), 
                    glob_pattern="class*", transform=default_tfm)
print(imageset_str, len(gradevoldataset_fc))
imageset_str = "resnet50_linf8_gradevol_avgpool"
gradevoldataset_avgpool = ImageDataset_filter(join(GANimgroot, "resnet50_linf8_gradevol_avgpool"), 
                    glob_pattern="class*", transform=default_tfm)
print(imageset_str, len(gradevoldataset_avgpool))
imageset_str = "resnet50_linf8_gradevol_layer4"
gradevoldataset_layer4 = ImageDataset_filter(join(GANimgroot, "resnet50_linf8_gradevol_layer4"), 
                    glob_pattern="class*", transform=default_tfm)
print(imageset_str, len(gradevoldataset_layer4))
imageset_str = "resnet50_linf8_gradevol_layer3"
gradevoldataset_layer3 = ImageDataset_filter(join(GANimgroot, "resnet50_linf8_gradevol_layer3"), 
                    glob_pattern="class*", transform=default_tfm)
print(imageset_str, len(gradevoldataset_layer3))
# Out:
# 21000 21000 21000
# DeePSim_4std 50000
# BigGAN_trunc07 50000
# BigGAN_std_008 50000
# resnet50_linf8_gradevol 50000
# resnet50_linf8_gradevol_avgpool 51200
# resnet50_linf8_gradevol_layer4 51200
# resnet50_linf8_gradevol_layer3 51200

# %%
num_workers = 8
device = "cuda"
embed_root = "/n/holylabs/LABS/kempner_fellows/Users/binxuwang/Projects/GAN_img_embedding"
embed_dir = join(embed_root, "dinov2_vitb14")
os.makedirs(embed_dir, exist_ok=True)

for dataset, dataset_str  in [
    (FCdataset, "DeePSim_4std"),
    (BGdataset, "BigGAN_trunc07"),
    (BGRNDdataset, "BigGAN_std_008"),
    (gradevoldataset_fc, "resnet50_linf8_gradevol_fc"),
    (gradevoldataset_avgpool, "resnet50_linf8_gradevol_avgpool"),
    (gradevoldataset_layer4, "resnet50_linf8_gradevol_layer4"),
    (gradevoldataset_layer3, "resnet50_linf8_gradevol_layer3"),
    (FCinvertdataset, "BigGAN_1000cls_FC_invert"),
    (BGorigdataset, "BigGAN_1000cls_BG_orig"),
    (BGBlurdataset, "BigGAN_1000cls_BG_blur"),
]:
    embeddings = embed_dataset(dataset, embed_model, batch_size=100, size=224, 
                               device=device, num_workers=num_workers)
    # raise ValueError("Stop here")
    torch.cuda.empty_cache()
    pkl.dump( (dataset.paths, embeddings), 
             open(join(embed_dir, f"{dataset_str}_embedding.pkl"), "wb"))
    print(f"saved {dataset_str} to {embed_dir} : {embeddings.shape}")

# %%
pinknoise_dataset = ImageDataset_filter(join(stim_rootdir, "GAN_sample_fid", "pink_noise"),
                    glob_pattern="sample*", transform=default_tfm)
len(pinknoise_dataset)
# Out:
# 50000

# %%
num_workers = 8
device = "cuda"
dataset, dataset_str = pinknoise_dataset, "pink_noise"
embeddings = embed_dataset(dataset, embed_model, batch_size=100, size=224, 
                               device=device, num_workers=num_workers)
torch.cuda.empty_cache()
pkl.dump( (dataset.paths, embeddings), 
            open(join(embed_dir, f"{dataset_str}_embedding.pkl"), "wb"))
print(f"saved {dataset_str} to {embed_dir} : {embeddings.shape}")
# Out:
# 100%|██████████| 500/500 [05:34<00:00,  1.50it/s]
# saved pink_noise to /n/holylabs/LABS/kempner_fellows/Users/binxuwang/Projects/GAN_img_embedding/dinov2_vitb14 : torch.Size([50000, 768])

# %% [markdown]
# ### More Reference Image Datasets

# %%
default_tfm = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    normalizer,
])

# %%
os.listdir(join(stim_rootdir, 'Stimuli'))
# Out:
# ['MassiveMemory_Oliva_2008',
#  '2020-BigGAN',
#  '2021-EvolDecomp',
#  'places365_standard',
#  'places365standard_easyformat.tar',
#  'val_256',
#  'ecoset',
#  'val_256.tar',
#  'curvature-contour']

# %%
jpg_files = glob.glob(join(stim_rootdir, 'Stimuli', 'curvature-contour', 'pasu*.jpg'))
print(len(jpg_files))
curvcontour_dataset = ImageDataset_filter(join(stim_rootdir, 'Stimuli', 'curvature-contour'),
                    glob_pattern='pasu*', transform=default_tfm)
print(len(curvcontour_dataset))
# Out:
# 2960
# 2960

# %%
jpg_files = glob.glob(join(stim_rootdir, 'Stimuli', 'MassiveMemory_Oliva_2008',"*.jpg"))
print(len(jpg_files))
memobject_dataset = ImageDataset_filter(join(stim_rootdir, 'Stimuli', 'MassiveMemory_Oliva_2008'),
                    glob_pattern='*', transform=default_tfm)
print(len(memobject_dataset))
# Out:
# 2389
# 2400

# %%
from torchvision.datasets import ImageFolder

ecoval_dataset = ImageFolder(join(stim_rootdir, 'Stimuli', 'ecoset', 'val'),
                                      transform=default_tfm)
print(len(ecoval_dataset))
# number of classes
print(ecoval_dataset.classes)
print(len(ecoval_dataset.classes))
# Out:
# 28250
# ['0001_man', '0005_house', '0009_car', '0020_woman', '0025_phone', '0027_bed', '0035_gun', '0038_book', '0039_dog', '0045_ball', '0047_fire', '0050_horse', '0051_city', '0052_fish', '0056_child', '0061_boat', '0062_table', '0065_tree', '0068_clock', '0070_bag', '0071_camera', '0076_cup', '0077_ship', '0082_kitchen', '0083_key', '0085_bird', '0086_pig', '0089_bus', '0091_bridge', '0093_pizza', '0094_computer', '0097_church', '0111_doll', '0112_bell', '0114_stairs', '0115_apple', '0116_flower', '0117_ring', '0118_snake', '0124_mountain', '0128_road', '0131_wall', '0132_tiger', '0135_toilet', '0137_train', '0138_bottle', '0140_turtle', '0141_cookie', '0145_egg', '0146_river', '0148_cat', '0149_truck', '0153_basket', '0154_bear', '0156_moon', '0157_milk', '0158_blanket', '0163_lemon', '0164_frog', '0167_pillow', '0168_elephant', '0169_cow', '0170_banana', '0171_goat', '0174_knife', '0175_ladder', '0177_popcorn', '0182_refrigerator', '0183_jar', '0184_jail', '0185_hamburger', '0186_toast', '0187_umbrella', '0193_bean', '0194_castle', '0204_flashlight', '0206_tomato', '0208_strawberry', '0209_leopard', '0210_donkey', '0215_axe', '0220_mailbox', '0222_grape', '0223_vase', '0224_carrot', '0226_tractor', '0229_cupcake', '0232_fern', '0234_bagel', '0235_telescope', '0236_cactus', '0238_tent', '0240_microscope', '0243_kite', '0246_lantern', '0247_octopus', '0250_lamp', '0256_blender', '0257_burrito', '0258_mango', '0262_binoculars', '0265_steak', '0266_gravel', '0269_escalator', '0272_walrus', '0273_horseshoe', '0274_antelope', '0282_tongs', '0289_porcupine', '0290_camcorder', '0291_mousetrap', '0292_lion', '0294_cauliflower', '0296_shower', '0301_hotdog', '0306_warthog', '0309_guardrail', '0310_thimble', '0311_crawfish', '0312_dustpan', '0318_eyedropper', '0325_nectarine', '0326_flyswatter', '0327_lollypop', '0330_lightbulb', '0333_corn', '0334_cave', '0335_pie', '0337_spider', '0339_bread', '0341_motorcycle', '0352_monkey', '0353_whale', '0356_airplane', '0359_shovel', '0361_bucket', '0363_rabbit', '0364_necklace', '0369_moose', '0370_glass', '0375_drum', '0380_mop', '0381_bracelet', '0383_spoon', '0384_stove', '0387_lettuce', '0389_ashtray', '0393_lake', '0397_noodles', '0404_walnut', '0406_pastry', '0412_ferret', '0419_fig', '0422_eggplant', '0423_violin', '0428_chipmunk', '0429_milkshake', '0431_blackberry', '0434_sushi', '0435_apricot', '0437_drawers', '0438_doughnut', '0440_lawnmower', '0443_snowplow', '0447_chalkboard', '0455_backpack', '0460_alligator', '0463_cockroach', '0464_lime', '0466_lighthouse', '0471_dolphin', '0473_piano', '0474_earring', '0475_chicken', '0478_blueberry', '0479_grapefruit', '0482_thermometer', '0484_cranberry', '0488_iceberg', '0494_wasp', '0505_tweezers', '0506_asparagus', '0508_croissant', '0510_teapot', '0511_needle', '0513_acorn', '0517_bumblebee', '0518_anvil', '0533_seashell', '0535_birdhouse', '0542_thyme', '0543_thumbtack', '0548_saltshaker', '0553_paperclip', '0555_matchstick', '0564_envelope', '0582_pineapple', '0583_wheelchair', '0593_butterfly', '0597_camel', '0598_balloon', '0599_beach', '0602_guitar', '0607_crate', '0609_wrench', '0611_eggroll', '0617_taco', '0618_rat', '0624_meatball', '0625_emerald', '0630_omelet', '0631_sheep', '0633_jukebox', '0634_desert', '0643_raspberry', '0647_snail', '0654_pistachio', '0655_groundhog', '0656_videotape', '0657_jellyfish', '0659_carousel', '0661_hippo', '0665_pear', '0666_bullet', '0670_pliers', '0675_toothpick', '0676_stagecoach', '0678_hourglass', '0686_coliseum', '0687_blowtorch', '0688_treadmill', '0692_cake', '0710_bobcat', '0718_cumin', '0721_hedgehog', '0729_opossum', '0737_pumpkin', '0739_bowl', '0740_worm', '0743_candy', '0754_clarinet', '0759_peanut', '0764_gondola', '0767_padlock', '0768_television', '0772_barnacle', '0784_leek', '0787_cashew', '0794_streetlamp', '0801_razor', '0807_peach', '0810_pudding', '0812_coin', '0822_grasshopper', '0828_pea', '0829_toaster', '0836_chalk', '0841_bee', '0842_bicycle', '0844_screwdriver', '0846_penci ...
# 565

# %%
from torchvision.datasets import ImageFolder

placesval_dataset = ImageFolder(join(stim_rootdir, 'Stimuli', 'places365_standard', 'val'),
                                      transform=default_tfm)
print(len(placesval_dataset))
# number of classes
print(placesval_dataset.classes)
print(len(placesval_dataset.classes))
# Out:
# 36500
# ['airfield', 'airplane_cabin', 'airport_terminal', 'alcove', 'alley', 'amphitheater', 'amusement_arcade', 'amusement_park', 'apartment_building-outdoor', 'aquarium', 'aqueduct', 'arcade', 'arch', 'archaelogical_excavation', 'archive', 'arena-hockey', 'arena-performance', 'arena-rodeo', 'army_base', 'art_gallery', 'art_school', 'art_studio', 'artists_loft', 'assembly_line', 'athletic_field-outdoor', 'atrium-public', 'attic', 'auditorium', 'auto_factory', 'auto_showroom', 'badlands', 'bakery-shop', 'balcony-exterior', 'balcony-interior', 'ball_pit', 'ballroom', 'bamboo_forest', 'bank_vault', 'banquet_hall', 'bar', 'barn', 'barndoor', 'baseball_field', 'basement', 'basketball_court-indoor', 'bathroom', 'bazaar-indoor', 'bazaar-outdoor', 'beach', 'beach_house', 'beauty_salon', 'bedchamber', 'bedroom', 'beer_garden', 'beer_hall', 'berth', 'biology_laboratory', 'boardwalk', 'boat_deck', 'boathouse', 'bookstore', 'booth-indoor', 'botanical_garden', 'bow_window-indoor', 'bowling_alley', 'boxing_ring', 'bridge', 'building_facade', 'bullring', 'burial_chamber', 'bus_interior', 'bus_station-indoor', 'butchers_shop', 'butte', 'cabin-outdoor', 'cafeteria', 'campsite', 'campus', 'canal-natural', 'canal-urban', 'candy_store', 'canyon', 'car_interior', 'carrousel', 'castle', 'catacomb', 'cemetery', 'chalet', 'chemistry_lab', 'childs_room', 'church-indoor', 'church-outdoor', 'classroom', 'clean_room', 'cliff', 'closet', 'clothing_store', 'coast', 'cockpit', 'coffee_shop', 'computer_room', 'conference_center', 'conference_room', 'construction_site', 'corn_field', 'corral', 'corridor', 'cottage', 'courthouse', 'courtyard', 'creek', 'crevasse', 'crosswalk', 'dam', 'delicatessen', 'department_store', 'desert-sand', 'desert-vegetation', 'desert_road', 'diner-outdoor', 'dining_hall', 'dining_room', 'discotheque', 'doorway-outdoor', 'dorm_room', 'downtown', 'dressing_room', 'driveway', 'drugstore', 'elevator-door', 'elevator_lobby', 'elevator_shaft', 'embassy', 'engine_room', 'entrance_hall', 'escalator-indoor', 'excavation', 'fabric_store', 'farm', 'fastfood_restaurant', 'field-cultivated', 'field-wild', 'field_road', 'fire_escape', 'fire_station', 'fishpond', 'flea_market-indoor', 'florist_shop-indoor', 'food_court', 'football_field', 'forest-broadleaf', 'forest_path', 'forest_road', 'formal_garden', 'fountain', 'galley', 'garage-indoor', 'garage-outdoor', 'gas_station', 'gazebo-exterior', 'general_store-indoor', 'general_store-outdoor', 'gift_shop', 'glacier', 'golf_course', 'greenhouse-indoor', 'greenhouse-outdoor', 'grotto', 'gymnasium-indoor', 'hangar-indoor', 'hangar-outdoor', 'harbor', 'hardware_store', 'hayfield', 'heliport', 'highway', 'home_office', 'home_theater', 'hospital', 'hospital_room', 'hot_spring', 'hotel-outdoor', 'hotel_room', 'house', 'hunting_lodge-outdoor', 'ice_cream_parlor', 'ice_floe', 'ice_shelf', 'ice_skating_rink-indoor', 'ice_skating_rink-outdoor', 'iceberg', 'igloo', 'industrial_area', 'inn-outdoor', 'islet', 'jacuzzi-indoor', 'jail_cell', 'japanese_garden', 'jewelry_shop', 'junkyard', 'kasbah', 'kennel-outdoor', 'kindergarden_classroom', 'kitchen', 'lagoon', 'lake-natural', 'landfill', 'landing_deck', 'laundromat', 'lawn', 'lecture_room', 'legislative_chamber', 'library-indoor', 'library-outdoor', 'lighthouse', 'living_room', 'loading_dock', 'lobby', 'lock_chamber', 'locker_room', 'mansion', 'manufactured_home', 'market-indoor', 'market-outdoor', 'marsh', 'martial_arts_gym', 'mausoleum', 'medina', 'mezzanine', 'moat-water', 'mosque-outdoor', 'motel', 'mountain', 'mountain_path', 'mountain_snowy', 'movie_theater-indoor', 'museum-indoor', 'museum-outdoor', 'music_studio', 'natural_history_museum', 'nursery', 'nursing_home', 'oast_house', 'ocean', 'office', 'office_building', 'office_cubicles', 'oilrig', 'operating_room', 'orchard', 'orchestra_pit', 'pagoda', 'palace', 'pantry', 'park', 'parking_garage-indoor', 'parking_garage-outdoor', 'parking_lot', 'pasture', 'patio', 'pavilion', 'pet_shop', 'pharmacy', 'phone_booth' ...
# 365

# %%
isinstance(ecoval_dataset, ImageFolder)
isinstance(placesval_dataset, ImageFolder)
# Out:
# True

# %%
type(curvcontour_dataset)
# Out:
# core.utils.dataset_utils.ImageDataset_filter

# %%
num_workers = 8
device = "cuda"
GANembed_root = "/n/holylabs/LABS/kempner_fellows/Users/binxuwang/Projects/GAN_img_embedding"
GANembed_dir = join(GANembed_root, "dinov2_vitb14")
os.makedirs(GANembed_dir, exist_ok=True)

for dataset, dataset_str  in [
    (ecoval_dataset, "ecoset_val"),
    (placesval_dataset, "places365_val"),
    (curvcontour_dataset, "curvature_contour"),
    (memobject_dataset, "massmem_objects"),
]:
    embeddings = embed_dataset(dataset, embed_model, batch_size=100, size=224, 
                               device=device, num_workers=num_workers)
    torch.cuda.empty_cache()
    if isinstance(dataset, ImageFolder):
        pkl.dump( (dataset.samples, embeddings), 
             open(join(GANembed_dir, f"{dataset_str}_embedding.pkl"), "wb"))
    else:
        pkl.dump( (dataset.paths, embeddings), 
             open(join(GANembed_dir, f"{dataset_str}_embedding.pkl"), "wb"))
    print(f"saved {dataset_str} to {GANembed_dir} : {embeddings.shape}")
# Out:
#   0%|          | 0/283 [00:00<?, ?it/s]
# 100%|██████████| 283/283 [02:55<00:00,  1.61it/s]
# saved ecoset_val to /n/holylabs/LABS/kempner_fellows/Users/binxuwang/Projects/GAN_img_embedding/dinov2_vitb14 : torch.Size([28250, 768])
# 100%|██████████| 365/365 [02:18<00:00,  2.64it/s]
# saved places365_val to /n/holylabs/LABS/kempner_fellows/Users/binxuwang/Projects/GAN_img_embedding/dinov2_vitb14 : torch.Size([36500, 768])
# 100%|██████████| 30/30 [00:20<00:00,  1.47it/s]
# saved curvature_contour to /n/holylabs/LABS/kempner_fellows/Users/binxuwang/Projects/GAN_img_embedding/dinov2_vitb14 : torch.Size([2960, 768])
# 100%|██████████| 24/24 [00:18<00:00,  1.33it/s]
# saved massmem_objects to /n/holylabs/LABS/kempner_fellows/Users/binxuwang/Projects/GAN_img_embedding/dinov2_vitb14 : torch.Size([2400, 768])

# %%
len(dataset.samples)
# Out:
# 28250

# %%
dataset.samples[0]
# Out:
# ('/n/holyscratch01/kempner_fellows/Users/binxuwang/Datasets/Stimuli/ecoset/val/0001_man/n09641002_18604.JPEG',
#  0)

# %%
len(dataset.targets)
# Out:
# 28250

# %% [markdown]
# ## Cropped Embedding Pipeline

# %%
imgroot = join(GANimgroot, "BigGAN_1000cls_std07_invert")
FCinvertdataset = ImageDataset_filter(imgroot, glob_pattern="FC_invert*", 
                            transform=default_tfm)
BGorigdataset = ImageDataset_filter(imgroot, glob_pattern="BG*", 
                            transform=default_tfm)
BGBlurdataset = ImageDataset_filter(imgroot, glob_pattern="BG*",
                            transform=transforms.Compose([
                               transforms.ToTensor(), 
                               transforms.GaussianBlur([15, 15], sigma=9),
                               transforms.Resize((224, 224)),
                               normalizer,]))
print(len(FCinvertdataset), len(BGorigdataset), len(BGBlurdataset))

imageset_str = "DeePSim_4std"
FCdataset = ImageDataset_filter(join(GANimgroot, "DeePSim_4std"), 
                    glob_pattern="sample*", transform=default_tfm)
print(imageset_str, len(FCdataset))
imageset_str = "BigGAN_trunc07"
BGdataset = ImageDataset_filter(join(GANimgroot, "BigGAN_trunc07"), 
                    glob_pattern="sample*", transform=default_tfm)
print(imageset_str, len(BGdataset))
imageset_str = "BigGAN_std_008"
BGRNDdataset = ImageDataset_filter(join(GANimgroot, "BigGAN_std_008"), 
                    glob_pattern="sample*", transform=default_tfm)
print(imageset_str, len(BGRNDdataset))

imageset_str = "resnet50_linf8_gradevol"
gradevoldataset_fc = ImageDataset_filter(join(GANimgroot, "resnet50_linf8_gradevol"), 
                    glob_pattern="class*", transform=default_tfm)
print(imageset_str, len(gradevoldataset_fc))
imageset_str = "resnet50_linf8_gradevol_avgpool"
gradevoldataset_avgpool = ImageDataset_filter(join(GANimgroot, "resnet50_linf8_gradevol_avgpool"), 
                    glob_pattern="class*", transform=default_tfm)
print(imageset_str, len(gradevoldataset_avgpool))
imageset_str = "resnet50_linf8_gradevol_layer4"
gradevoldataset_layer4 = ImageDataset_filter(join(GANimgroot, "resnet50_linf8_gradevol_layer4"), 
                    glob_pattern="class*", transform=default_tfm)
print(imageset_str, len(gradevoldataset_layer4))
imageset_str = "resnet50_linf8_gradevol_layer3"
gradevoldataset_layer3 = ImageDataset_filter(join(GANimgroot, "resnet50_linf8_gradevol_layer3"), 
                    glob_pattern="class*", transform=default_tfm)
print(imageset_str, len(gradevoldataset_layer3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 imgroot = join(GANimgroot, "BigGAN_1000cls_std07_invert")
#       2 FCinvertdataset = ImageDataset_filter(imgroot, glob_pattern="FC_invert*",
#       3                             transform=default_tfm)
#       4 BGorigdataset = ImageDataset_filter(imgroot, glob_pattern="BG*",
#       5                             transform=default_tfm)
#
# NameError: name 'GANimgroot' is not defined

# %%
INval_dataset = create_imagenet_valid_dataset(imgpix=224,rootdir=rootdir)
curvcontour_dataset = ImageDataset_filter(join(stim_rootdir, 'Stimuli', 'curvature-contour'),
                    glob_pattern='pasu*', transform=default_tfm)
memobject_dataset = ImageDataset_filter(join(stim_rootdir, 'Stimuli', 'MassiveMemory_Oliva_2008'),
                    glob_pattern='*', transform=default_tfm)
ecoval_dataset = ImageFolder(join(stim_rootdir, 'Stimuli', 'ecoset', 'val'),
                                      transform=default_tfm)
placesval_dataset = ImageFolder(join(stim_rootdir, 'Stimuli', 'places365_standard', 'val'),
                                      transform=default_tfm)
pinknoise_dataset = ImageDataset_filter(join(stim_rootdir, "GAN_sample_fid", "pink_noise"),
                    glob_pattern="sample*", transform=default_tfm)

# %%
for dataset_str, dataset  in [
    "imagenet_valid",INval_dataset
    "ecoset_val",ecoval_dataset
    "places365_val",placesval_dataset
    "curvature_contour",curvcontour_dataset
    "massmem_objects",memobject_dataset
    "pink_noise",
    "DeePSim_4std",
    "BigGAN_trunc07",
    "BigGAN_std_008",
    "BigGAN_1000cls_BG_orig",
    "BigGAN_1000cls_FC_invert",
    "BigGAN_1000cls_BG_blur",
    "resnet50_linf8_gradevol_fc",
    "resnet50_linf8_gradevol_avgpool",
    "resnet50_linf8_gradevol_layer4",
    "resnet50_linf8_gradevol_layer3",
]:

# %%
num_workers = 8
device = "cuda"
GANembed_root = "/n/holylabs/LABS/kempner_fellows/Users/binxuwang/Projects/GAN_img_embedding"
GANembed_dir = join(GANembed_root, "dinov2_vitb14")
os.makedirs(GANembed_dir, exist_ok=True)
for dataset, dataset_str  in [
    "DeePSim_4std",
    "BigGAN_trunc07",
    "BigGAN_std_008",
    "BigGAN_1000cls_BG_orig",
    "BigGAN_1000cls_FC_invert",
    "BigGAN_1000cls_BG_blur",
    "resnet50_linf8_gradevol_fc",
    "resnet50_linf8_gradevol_avgpool",
    "resnet50_linf8_gradevol_layer4",
    "resnet50_linf8_gradevol_layer3",
    "pink_noise",
    "ecoset_val",
    "places365_val",
    "curvature_contour",
    "massmem_objects",
]:
    embeddings = embed_dataset(dataset, embed_model, batch_size=100, size=224, 
                               device=device, num_workers=num_workers)
    torch.cuda.empty_cache()
    if isinstance(dataset, ImageFolder):
        pkl.dump( (dataset.samples, embeddings), 
             open(join(GANembed_dir, f"{dataset_str}_embedding.pkl"), "wb"))
    else:
        pkl.dump( (dataset.paths, embeddings), 
             open(join(GANembed_dir, f"{dataset_str}_embedding.pkl"), "wb"))
    print(f"saved {dataset_str} to {GANembed_dir} : {embeddings.shape}")

# %% [markdown]
# ## Load and Analyze reference embeddings

# %%
GANembed_root = "/n/holylabs/LABS/kempner_fellows/Users/binxuwang/Projects/GAN_img_embedding"
GANembed_dir = join(GANembed_root, "dinov2_vitb14")
def load_image_embedding(dataset_str, embed_dir=GANembed_dir):
    if dataset_str == "imagenet_valid":
        embeddings = pkl.load(open(join(embed_dir, "imagenet_valid_embedding.pkl"), "rb"))
    else:
        _, embeddings = pkl.load(open(join(embed_dir, f"{dataset_str}_embedding.pkl"), "rb"))
    return embeddings

# %%
# compute FID score
embed_col = {}
IN_emb = pkl.load(open(join(GANembed_dir, "imagenet_valid_embedding.pkl"), "rb"))
embed_col = {"imagenet_valid": IN_emb}
for dataset_str in [
    "DeePSim_4std",
    "BigGAN_trunc07",
    "BigGAN_std_008",
    "BigGAN_1000cls_BG_orig",
    "BigGAN_1000cls_FC_invert",
    "BigGAN_1000cls_BG_blur",
    "resnet50_linf8_gradevol_fc",
    "resnet50_linf8_gradevol_avgpool",
    "resnet50_linf8_gradevol_layer4",
    "resnet50_linf8_gradevol_layer3",
    "pink_noise",
    "ecoset_val",
    "places365_val",
    "curvature_contour",
    "massmem_objects",
]:
    _, embed_col[dataset_str] = pkl.load(open(join(GANembed_dir, dataset_str+"_embedding.pkl"), "rb"))
    print(dataset_str, embed_col[dataset_str].shape)
# Out:
# DeePSim_4std torch.Size([50000, 768])
# BigGAN_trunc07 torch.Size([50000, 768])
# BigGAN_std_008 torch.Size([50000, 768])
# BigGAN_1000cls_BG_orig torch.Size([21000, 768])
# BigGAN_1000cls_FC_invert torch.Size([21000, 768])
# BigGAN_1000cls_BG_blur torch.Size([21000, 768])
# resnet50_linf8_gradevol_fc torch.Size([50000, 768])
# resnet50_linf8_gradevol_avgpool torch.Size([51200, 768])
# resnet50_linf8_gradevol_layer4 torch.Size([51200, 768])
# resnet50_linf8_gradevol_layer3 torch.Size([51200, 768])
# pink_noise torch.Size([50000, 768])
# ecoset_val torch.Size([28250, 768])
# places365_val torch.Size([36500, 768])
# curvature_contour torch.Size([2960, 768])
# massmem_objects torch.Size([2400, 768])

# %% [markdown]
# ### Exmaple: ImageNet Analysis

# %%
IN_mean = IN_emb.mean(dim=0)
IN_covmat = torch.cov(IN_emb.T)
IN_precmat = torch.pinverse(IN_covmat.cuda(),rcond=1e-5).cpu()
# eigh decomposition
IN_eigval, IN_eigvec = torch.linalg.eigh(IN_covmat.cuda(), )
IN_eigval = torch.flip(IN_eigval, dims=[0]).cpu()
IN_eigvec = torch.flip(IN_eigvec, dims=[1]).cpu()

# %%
plt.semilogy(IN_eigval.cpu().numpy())
plt.xlabel("eigval rank")
plt.ylabel("eigval")
plt.title("eigval spectrum of imagenet valid embedding")
plt.show()

# %% [markdown]
# ### Dimensionality of image distributions (embeddings)

# %%
embed_eig_col = {}
for dataset_str in [
    "imagenet_valid",
    "DeePSim_4std",
    "BigGAN_trunc07",
    "BigGAN_std_008",
    "BigGAN_1000cls_BG_orig",
    "BigGAN_1000cls_FC_invert",
    "BigGAN_1000cls_BG_blur",
    "resnet50_linf8_gradevol_fc",
    "resnet50_linf8_gradevol_avgpool",
    "resnet50_linf8_gradevol_layer4",
    "resnet50_linf8_gradevol_layer3",
    "pink_noise",
    "ecoset_val",
    "places365_val",
    "curvature_contour",
    "massmem_objects",
]:
    embed = load_image_embedding(dataset_str)
    embed = embed.cuda()
    cov = torch.cov(embed.T, )
    data_mean = embed.mean(dim=0)
    data_eigvals, data_eigvecs = torch.linalg.eigh(cov)
    data_eigvals = torch.flip(data_eigvals, dims=[0])
    data_eigvecs = torch.flip(data_eigvecs, dims=[1])
    embed_eig_col[dataset_str] = (data_mean, data_eigvals, data_eigvecs)

# %%
# plot the eigenvalues
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
colors = plt.cm.tab20(np.linspace(0, 1, len(embed_eig_col)))
for i, dataset_str in enumerate(embed_eig_col):
    data_mean, data_eigvals, data_eigvecs = embed_eig_col[dataset_str]
    axes[0].plot(data_eigvals.detach().cpu().numpy(), 
        lw=2, alpha=0.6, label=dataset_str, color=colors[i])
    axes[1].plot(data_eigvals.detach().cpu().numpy() / data_eigvals[0].detach().cpu().numpy(), 
        lw=2, alpha=0.6, label=dataset_str, color=colors[i])
axes[0].set_title("Eigenvalues")
axes[1].set_title("Normalized Eigenvalues")
axes[1].legend(loc='center left', bbox_to_anchor=(1, 0.5))
axes[0].set_ylim(1e-3, None)
axes[1].set_ylim(1e-3, 1.1)
plt.suptitle(f"Eigenvalues of covariance matrix of DINO-ViT-B14 embedding")
plt.tight_layout()
saveallforms(join(GANembed_root, "summary"), "dataset_DINO_FID_eigvals")

# %%
# plot the eigenvalues
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
colors = plt.cm.tab20(np.linspace(0, 1, len(embed_eig_col)))
for i, dataset_str in enumerate(embed_eig_col):
    data_mean, data_eigvals, data_eigvecs = embed_eig_col[dataset_str]
    axes[0].semilogy(data_eigvals.detach().cpu().numpy(), 
        lw=2, alpha=0.6, label=dataset_str, color=colors[i])
    axes[1].semilogy(data_eigvals.detach().cpu().numpy() / data_eigvals[0].detach().cpu().numpy(), 
        lw=2, alpha=0.6, label=dataset_str, color=colors[i])
axes[0].set_title("Eigenvalues")
axes[1].set_title("Normalized Eigenvalues")
axes[1].legend(loc='center left', bbox_to_anchor=(1, 0.5))
axes[0].set_ylim(1e-3, None)
axes[1].set_ylim(1e-3, 1.1)
plt.suptitle(f"Eigenvalues of covariance matrix of DINO-ViT-B14 embedding")
plt.tight_layout()
saveallforms(join(GANembed_root, "summary"), "dataset_DINO_FID_eigvals_logy")

# %%
# plot the eigenvalues
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
eig_cutoff = 100
colors = plt.cm.tab20(np.linspace(0, 1, len(embed_eig_col)))
for i, dataset_str in enumerate(embed_eig_col):
    data_mean, data_eigvals, data_eigvecs = embed_eig_col[dataset_str]
    axes[0].semilogy(data_eigvals.detach().cpu().numpy()[:eig_cutoff], 
        lw=2, alpha=0.6, label=dataset_str, color=colors[i])
    axes[1].semilogy(data_eigvals.detach().cpu().numpy()[:eig_cutoff] / data_eigvals[0].detach().cpu().numpy(), 
        lw=2, alpha=0.6, label=dataset_str, color=colors[i])
# axes[0].legend()
axes[0].set_title("Eigenvalues")
axes[1].set_title("Normalized Eigenvalues")
axes[1].legend(loc='center left', bbox_to_anchor=(1, 0.5))
axes[0].set_ylim(5e-3, None)
axes[1].set_ylim(5e-3, 1.1)
plt.suptitle(f"Eigenvalues of covariance matrix of DINO-ViT-B14 embedding")
plt.tight_layout()
saveallforms(join(GANembed_root, "summary"), 
             f"dataset_DINO_FID_eigvals_logy_cutoff{eig_cutoff}")

# %% [markdown]
# **Observations**
#
# * We can see the dimensionality of the ImageNet validation set is still the largest among all! i.e. the most diverse dataset than the generated ones.
# * Synthetic image still lack in their variability comparing to natural ones
# * The spectrum (effective dim) of embeddings could be a indicator of image diversity / quality?

# %%
# print the dimensionality of the embedding
eigcnt = 50
print(f"Dimensionality of the embedding: Explained variance of top {eigcnt} PCs")
ratios = {}
sumvars = {}
for dataset_str in embed_eig_col:
    data_mean, data_eigvals, data_eigvecs = embed_eig_col[dataset_str]
    participation_ratio = data_eigvals[:eigcnt].sum() / data_eigvals.sum()
    ratios[dataset_str] = participation_ratio.item()
    sumvars[dataset_str] = data_eigvals[:eigcnt].sum().item()

# sort dataset names by ratios
sorted_ratios = sorted(ratios.items(), key=lambda x: x[1], reverse=False)
print(f"Explained variance of top {eigcnt} PCs, sorted low to high:")
for dataset, ratio in sorted_ratios:
    print(f"{dataset}: {ratio:.3f}")
# Out:
# Dimensionality of the embedding: Explained variance of top 50 PCs
# Explained variance of top 50 PCs, sorted low to high:
# imagenet_valid: 0.201
# ecoset_val: 0.231
# BigGAN_trunc07: 0.288
# BigGAN_1000cls_BG_orig: 0.292
# places365_val: 0.311
# massmem_objects: 0.347
# BigGAN_1000cls_BG_blur: 0.364
# resnet50_linf8_gradevol_fc: 0.378
# resnet50_linf8_gradevol_layer4: 0.420
# resnet50_linf8_gradevol_avgpool: 0.424
# BigGAN_std_008: 0.434
# resnet50_linf8_gradevol_layer3: 0.476
# BigGAN_1000cls_FC_invert: 0.476
# DeePSim_4std: 0.544
# curvature_contour: 0.878
# pink_noise: 0.892

# %%
# sort dataset names by sum of variances
sorted_sumvars = sorted(sumvars.items(), key=lambda x: x[1], reverse=True)
print(f"\nSum of variance of top {eigcnt} PCs, sorted high to low:")
for dataset, sumvar in sorted_sumvars:
    print(f"{dataset}: {sumvar:.2f}")
# Out:
# Sum of variance of top 50 PCs, sorted high to low:
# BigGAN_std_008: 782.62
# massmem_objects: 730.10
# curvature_contour: 726.92
# resnet50_linf8_gradevol_fc: 714.02
# BigGAN_1000cls_BG_blur: 688.35
# places365_val: 662.92
# resnet50_linf8_gradevol_avgpool: 652.78
# BigGAN_1000cls_BG_orig: 607.82
# BigGAN_trunc07: 606.39
# resnet50_linf8_gradevol_layer4: 588.91
# BigGAN_1000cls_FC_invert: 565.01
# resnet50_linf8_gradevol_layer3: 531.02
# ecoset_val: 509.12
# imagenet_valid: 448.12
# DeePSim_4std: 382.15
# pink_noise: 71.47

# %%
# print the dimesnionality of the embedding
eigcnt = 20
print(f"Dimensionality of the embedding : Explained variance of top {eigcnt} PCs")
ratios = {}
sumvars = {}
for dataset_str in embed_eig_col:
    data_mean, data_eigvals, data_eigvecs = embed_eig_col[dataset_str]
    participation_ratio = data_eigvals[:eigcnt].sum() / data_eigvals.sum()
    ratios[dataset_str] = participation_ratio.item()
    sumvars[dataset_str] = data_eigvals[:eigcnt].sum().item()
    # print(dataset_str, f"sum var {sumvars[dataset_str]:.2f} ratio {ratios[dataset_str]:.3f}")
    
# sort dataset names by ratios
sorted_ratios = sorted(ratios.items(), key=lambda x: x[1], reverse=False)
print(f"Explained variance of top {eigcnt} PCs, sorted low to high:")
for dataset, ratio in sorted_ratios:
    print(f"{dataset}: {ratio:.3f}")
# Out:
# Dimensionality of the embedding : Explained variance of top 20 PCs
# Explained variance of top 20 PCs, sorted low to high:
# imagenet_valid: 0.100
# ecoset_val: 0.117
# BigGAN_trunc07: 0.162
# BigGAN_1000cls_BG_orig: 0.168
# places365_val: 0.172
# massmem_objects: 0.195
# resnet50_linf8_gradevol_fc: 0.230
# BigGAN_1000cls_BG_blur: 0.233
# resnet50_linf8_gradevol_layer4: 0.270
# resnet50_linf8_gradevol_avgpool: 0.274
# BigGAN_std_008: 0.294
# resnet50_linf8_gradevol_layer3: 0.326
# BigGAN_1000cls_FC_invert: 0.330
# DeePSim_4std: 0.387
# curvature_contour: 0.752
# pink_noise: 0.776

# %%
# sort dataset names by sum of variances
sorted_sumvars = sorted(sumvars.items(), key=lambda x: x[1], reverse=True)
print(f"\nSum of variance of top {eigcnt} PCs, sorted high to low:")
for dataset, sumvar in sorted_sumvars:
    print(f"{dataset}: {sumvar:.2f}")
# Out:
# Sum of variance of top 20 PCs, sorted high to low:
# curvature_contour: 622.64
# BigGAN_std_008: 530.95
# BigGAN_1000cls_BG_blur: 439.68
# resnet50_linf8_gradevol_fc: 433.87
# resnet50_linf8_gradevol_avgpool: 422.20
# massmem_objects: 411.58
# BigGAN_1000cls_FC_invert: 391.40
# resnet50_linf8_gradevol_layer4: 378.96
# places365_val: 366.14
# resnet50_linf8_gradevol_layer3: 363.91
# BigGAN_1000cls_BG_orig: 349.50
# BigGAN_trunc07: 341.34
# DeePSim_4std: 271.53
# ecoset_val: 256.34
# imagenet_valid: 222.63
# pink_noise: 62.16

# %% [markdown]
# ### Frechet distance between image datasets

# %%
import seaborn as sns
import pandas as pd

def compute_frechet_distance(mu1, mu2, cov1, cov2):
    a = (mu1 - mu2).square().sum(dim=-1)
    b = cov1.trace() + cov2.trace()
    c = torch.linalg.eigvals(cov1 @ cov2).sqrt().real.sum(dim=-1)
    return a + b - 2 * c


def compute_frechet_distance_terms(mu1, mu2, cov1, cov2):
    a = (mu1 - mu2).square().sum(dim=-1)
    b = cov1.trace() + cov2.trace()
    c = torch.linalg.eigvals(cov1 @ cov2).sqrt().real.sum(dim=-1)
    return a, (b - 2 * c)

# %%
list(embed_col.keys())
# Out:
# ['imagenet_valid',
#  'DeePSim_4std',
#  'BigGAN_trunc07',
#  'BigGAN_std_008',
#  'BigGAN_1000cls_BG_orig',
#  'BigGAN_1000cls_FC_invert',
#  'BigGAN_1000cls_BG_blur',
#  'resnet50_linf8_gradevol_fc',
#  'resnet50_linf8_gradevol_avgpool',
#  'resnet50_linf8_gradevol_layer4',
#  'resnet50_linf8_gradevol_layer3',
#  'pink_noise',
#  'ecoset_val',
#  'places365_val',
#  'curvature_contour',
#  'massmem_objects']

# %%
mu_cov_col = {}
for dataset_str in embed_col:
    embed = embed_col[dataset_str]
    mu_cov_col[dataset_str] = (embed.mean(dim=0), torch.cov(embed.T))

# %%
dataset_strs = list(embed_col.keys())
dataset_strs = ['imagenet_valid',
                'massmem_objects',
                'ecoset_val',
                'places365_val',
 'DeePSim_4std',
 'BigGAN_trunc07',
 'BigGAN_std_008',
 'BigGAN_1000cls_BG_orig',
 'BigGAN_1000cls_FC_invert',
 'BigGAN_1000cls_BG_blur',
 'resnet50_linf8_gradevol_fc',
 'resnet50_linf8_gradevol_avgpool',
 'resnet50_linf8_gradevol_layer4',
 'resnet50_linf8_gradevol_layer3',
 'curvature_contour',
 'pink_noise',
]

# %%
fid_col = {}
fid_terms_col = {}
for i in range(len(dataset_strs)):
    for j in range(i+1, len(dataset_strs)):
        dataset_str1, dataset_str2 = dataset_strs[i], dataset_strs[j]
        mu1, cov1 = mu_cov_col[dataset_str1]
        mu2, cov2 = mu_cov_col[dataset_str2]
        fid = compute_frechet_distance(mu1, mu2, cov1, cov2)
        fid_mean, fid_cov = compute_frechet_distance_terms(mu1, mu2, cov1, cov2)
        print(f"{dataset_str1} vs {dataset_str2} : {fid:.0f} (m {fid_mean:.0f} cov {fid_cov:.0f})")
        fid_col[(dataset_str1, dataset_str2)] = fid.cpu().item()
        fid_terms_col[(dataset_str1, dataset_str2)] = fid_mean.cpu().item(), fid_cov.cpu().item()
# Out:
# imagenet_valid vs massmem_objects : 697 (m 110 cov 587)
# imagenet_valid vs ecoset_val : 262 (m 12 cov 250)
# imagenet_valid vs places365_val : 551 (m 48 cov 503)
# imagenet_valid vs DeePSim_4std : 1887 (m 863 cov 1024)
# imagenet_valid vs BigGAN_trunc07 : 279 (m 76 cov 203)
# imagenet_valid vs BigGAN_std_008 : 736 (m 219 cov 517)
# imagenet_valid vs BigGAN_1000cls_BG_orig : 297 (m 86 cov 212)
# imagenet_valid vs BigGAN_1000cls_FC_invert : 1355 (m 604 cov 751)
# imagenet_valid vs BigGAN_1000cls_BG_blur : 668 (m 256 cov 412)
# imagenet_valid vs resnet50_linf8_gradevol_fc : 667 (m 238 cov 429)
# imagenet_valid vs resnet50_linf8_gradevol_avgpool : 1038 (m 436 cov 602)
# imagenet_valid vs resnet50_linf8_gradevol_layer4 : 1083 (m 480 cov 602)
# imagenet_valid vs resnet50_linf8_gradevol_layer3 : 1396 (m 625 cov 772)
# imagenet_valid vs curvature_contour : 3269 (m 1427 cov 1842)
# imagenet_valid vs pink_noise : 4143 (m 2194 cov 1950)
# massmem_objects vs ecoset_val : 549 (m 79 cov 470)
# massmem_objects vs places365_val : 1041 (m 133 cov 908)
# massmem_objects vs DeePSim_4std : 2021 (m 902 cov 1119)
# massmem_objects vs BigGAN_trunc07 : 841 (m 129 cov 712)
# massmem_objects vs BigGAN_std_008 : 1094 (m 270 cov 824)
# massmem_objects vs BigGAN_1000cls_BG_orig : 844 (m 136 cov 708)
# massmem_objects vs BigGAN_1000cls_FC_invert : 1576 (m 623 cov 953)
# massmem_objects vs BigGAN_1000cls_BG_blur : 1087 (m 275 cov 812)
# massmem_objects vs resnet50_linf8_gradevol_fc : 1060 (m 274 cov 786)
# massmem_objects vs resnet50_linf8_gradevol_avgpool : 1273 (m 460 cov 813)
# massmem_objects vs resnet50_linf8_gradevol_layer4 : 1327 (m 502 cov 825)
# massmem_objects vs resnet50_linf8_gradevol_layer3 : 1577 (m 648 cov 929)
# massmem_objects vs curvature_contour : 2986 (m 1299 cov 1687)
# massmem_objects vs pink_noise : 4099 (m 2238 cov 1861)
# ecoset_val vs places365_val : 560 (m 40 cov 520)
# ecoset_val vs DeePSim_4std : 1887 (m 839 cov 1048)
# ecoset_val vs BigGAN_trunc07 : 490 (m 71 cov 420)
# ecoset_val vs BigGAN_std_008 : 873 (m 215 cov 658)
# ecoset_val vs BigGAN_1000cls_BG_orig : 498 (m 80 cov 418)
# ecoset_val vs BigGAN_1000cls_FC_invert : 1391 (m 574 cov 816)
# ecoset_val vs BigGAN_1000cls_BG_blur : 788 (m 238 cov 550)
# ecoset_val vs resnet50_linf8_gradevol_fc : 792 (m 222 cov 570)
# ecoset_val vs resnet50_linf8_gradevol_avgpool : 1061 (m 409 cov 652)
# ecoset_val vs resnet50_linf8_gradevol_layer4 : 1115 (m 453 cov 662)
# ecoset_val vs resnet50_linf8_gradevol_layer3 : 1416 (m 597 cov 818)
# ecoset_val vs curvature_contour : 3183 (m 1384 cov 1799)
# ecoset_val vs pink_noise : 4111 (m 2185 cov 1925)
# places365_val vs DeePSim_4std : 1869 (m 817 cov 1051)
# places365_val vs BigGAN_trunc07 : 742 (m 101 cov 641)
# places365_val vs BigGAN_std_008 : 1063 (m 235 cov 828)
# places365_val vs BigGAN_1000cls_BG_orig : 732 (m 108 cov 624)
# places365_val vs BigGAN_1000cls_FC_invert : 1495 (m 582 cov 913)
# places365_val vs BigGAN_1000cls_BG_blur : 914 (m 262 cov 652)
# places365_val vs resnet50_linf8_gradevol_fc : 1068 (m 257 cov 811)
# places365_val vs resnet50_linf8_gradevol_avgpool : 1285 (m 435 cov 850)
# places365_val vs resnet50_linf8_gradevol_layer4 : 1294 (m 472 cov 822)
# places365_val vs resnet50_linf8_gradevol_layer3 : 1520 (m 605 cov 916)
# places365_val vs curvature_contour : 3297 (m 1436 cov 1861)
# places365_val vs pink_noise : 4125 (m 2251 cov 1874)
# DeePSim_4std vs BigGAN_trunc07 : 1587 (m 663 cov 924)
# DeePSim_4std vs BigGAN_std_008 : 1260 (m 532 cov 728)
# DeePSim_4std vs BigGAN_1000cls_BG_orig : 1526 (m 636 cov 890)
# DeePSim_4std vs BigGAN_1000cls_FC_invert : 538 (m 260 cov 278)
# DeePSim_4std vs BigGAN_1000cls_BG_blur : 1520 (m 702 cov 818)
# DeePSim_4std vs resnet50_linf8_gradevol_fc : 1065 (m 404 cov 660)
# DeePSim_4std vs resnet50_linf8_gradevol_avgpool : 661 (m 266 cov 395)
# DeePSim_4std vs resnet50_linf8_gradevol_layer4 : 559 (m 240 cov 319)
# DeePSim_4std vs resnet50_linf8_gradevol_layer3 : 308 (m 142 cov 166)
# DeePSim_4std vs curvature_contour : 2827 (m 1922 cov 904)
# DeePSim_4std vs pink_noise : 2973 (m 2382 cov 590)
# BigGAN_trunc07 vs BigGAN_std_008 : 462 (m 88 cov 374)
# BigGAN_trunc07 vs BigGAN_1000cls_BG_orig : 25 (m 1 cov 24)
# BigGAN_trunc07 vs BigGAN_1000cls_FC_invert : 1084 (m 432 cov 652)
# BigGAN_trunc07 vs BigGAN_1000cls_BG_blur : 536 (m 192 cov 344)
# BigGAN_trunc07 vs resnet50_linf8_gradevol_fc : 477 (m 117 cov 360)
# BigGAN_trunc07 vs resnet50_linf8_gradevol_avgpool : 798 (m 277 cov 522)
# BigGAN_trunc07 vs resnet50_linf8_gradevol_layer4 : 843 (m 314 cov 529)
# BigGAN_trunc07 vs resnet50_linf8_gradevol_layer3 : 1127 (m 443 cov 684)
# BigGAN_trunc07 vs curvature_contour : 3142 (m 1372 cov 1770)
# BigGAN_trunc07 vs pink_noise : 4008 (m 2164 cov 1844)
# BigGAN_std_008 vs BigGAN_1000cls_BG_orig : 430 (m 77 cov 352)
# BigGAN_std_008 vs BigGAN_1000cls_FC_invert : 954 (m 373 cov 582)
# BigGAN_std_008 vs BigGAN_1000cls_BG_blur : 822 (m 272 cov 550)
# BigGAN_std_008 vs resnet50_linf8_gradevol_fc : 655 (m 153 cov 502)
# BigGAN_std_008 vs resnet50_linf8_gradevol_avgpool : 758 (m 240 cov 518)
# BigGAN_std_008 vs resnet50_linf8_gradevol_layer4 : 732 (m 252 cov 481)
# BigGAN_std_008 vs resnet50_linf8_gradevol_layer3 : 924 (m 351 cov 573)
# BigGAN_std_008 vs curvature_contour : 3043 (m 1462 cov 1581)
# BigGAN_std_008 vs pink_noise : 3882 (m 2299 cov 1583)
# BigGAN_1000cls_BG_orig vs BigGAN_1000cls_FC_invert : 1028 (m 410 cov 617)
# BigGAN_1000cls_BG_orig vs BigGAN_1000cls_BG_blur : 506 (m 186 cov 320)
# BigGAN_1000cls_BG_orig vs resnet50_linf8_gradevol_fc : 456 (m 110 cov 346)
# BigGAN_1000cls_BG_orig vs resnet50_linf8_gradevol_avgpool : 756 (m 260 cov 496)
# BigGAN_1000cls_BG_orig vs resnet50_linf8_gradevol_layer4 : 795 (m 294 cov 500)
# BigGAN_1000cls_BG_orig vs resnet50_linf8_gradevol_layer3 : 1070 (m 419 cov 651)
# BigGAN_1000cls_BG_orig vs curvature_contour : 3117 (m 1369 cov 1747)
# BigGAN_1000cls_BG_orig vs pink_noise : 3978 (m 2162 cov 1816)
# BigGAN_1000cls_FC_invert vs BigGAN_1000cls_BG_blur : 998 (m 434 cov 564)
# BigGAN_1000cls_FC_invert vs resnet50_linf8_gradevol_fc : 631 (m 224 cov 407)
# BigGAN_1000cls_FC_invert vs resnet50_linf8_gradevol_avgpool : 378 (m 139 cov 240)
# BigGAN_1000cls_FC_invert vs resnet50_linf8_gradevol_layer4 : 307 (m 118 cov 189)
# BigGAN_1000cls_FC_invert vs resnet50_linf8_gradevol_layer3 : 285 (m 121 cov 164)
# BigGAN_1000cls_FC_invert vs curvature_contour : 2718 (m 1584 cov 1134)
# BigGAN_1000cls_FC_invert vs pink_noise : 3193 (m 2189 cov 1004)
# BigGAN_1000cls_BG_blur vs resnet50_linf8_gradevol_fc : 696 (m 231 cov 465)
# BigGAN_1000cls_BG_blur vs resnet50_linf8_gradevol_avgpool : 889 (m 346 cov 543)
# BigGAN_1000cls_BG_blur vs resnet50_linf8_gradevol_layer4 : 882 (m 364 cov 518)
# BigGAN_1000cls_BG_blur vs resnet50_linf8_gradevol_layer3 : 1104 (m 474 cov 630)
# BigGAN_1000cls_BG_blur vs curvature_contour : 2993 (m 1378 cov 1615)
# BigGAN_1000cls_BG_blur vs pink_noise : 3759 (m 2125 cov 1634)
# resnet50_linf8_gradevol_fc vs resnet50_linf8_gradevol_avgpool : 219 (m 60 cov 160)
# resnet50_linf8_gradevol_fc vs resnet50_linf8_gradevol_layer4 : 294 (m 89 cov 205)
# resnet50_linf8_gradevol_fc vs resnet50_linf8_gradevol_layer3 : 543 (m 177 cov 366)
# resnet50_linf8_gradevol_fc vs curvature_contour : 3000 (m 1407 cov 1593)
# resnet50_linf8_gradevol_fc vs pink_noise : 3742 (m 2097 cov 1645)
# resnet50_linf8_gradevol_avgpool vs resnet50_linf8_gradevol_layer4 : 94 (m 29 cov 65)
# resnet50_linf8_gradevol_avgpool vs resnet50_linf8_gradevol_layer3 : 201 (m 62 cov 139)
# resnet50_linf8_gradevol_avgpool vs curvature_contour : 2811 (m 1476 cov 1335)
# resnet50_linf8_gradevol_avgpool vs pink_noise : 3441 (m 2124 cov 1317)
# resnet50_linf8_gradevol_layer4 vs resnet50_linf8_gradevol_layer3 : 132 (m 42 cov 89)
# resnet50_linf8_gradevol_layer4 vs curvature_contour : 2782 (m 1524 cov 1258)
# resnet50_linf8_gradevol_layer4 vs pink_noise : 3379 (m 2178 cov 1201)
# resnet50_linf8_gradevol_layer3 vs curvature_contour : 2704 (m 1611 cov 1092)
# resnet50_linf8_gradevol_layer3 vs pink_noise : 3182 (m 2233 cov 950)
# curvature_contour vs pink_noise : 3733 (m 2979 cov 754)

# %%
os.makedirs(join(GANembed_root, "summary"), exist_ok=True)

df = pd.DataFrame(fid_col.values(), index=pd.MultiIndex.from_tuples(fid_col.keys()), columns=["FID"])
df["FID_mean"] = [fid_terms_col[k][0] for k in fid_col.keys()]
df["FID_cov"] = [fid_terms_col[k][1] for k in fid_col.keys()]
# df["FID"] = df["FID"].map(lambda x: x.item())
df.to_csv(join(GANembed_root, "summary", "dataset_DINO_FID.csv"))

df_mat = df.reset_index().pivot(index="level_0", columns="level_1", values="FID", )
# order the row and column
df_mat_order = df_mat.loc[dataset_strs[:-1]][dataset_strs[1:]]
df_mat_order.to_csv(join(GANembed_root, "summary", "dataset_DINO_FID_ordmat.csv"))

# %%
plt.figure(figsize=(10, 10))
# plot the FID score as distance matrix
sns.heatmap(df_mat_order, cmap="jet", annot=True, fmt=".0f")
# inver the y axis
plt.gca().invert_yaxis()
# plt.gca().invert_xaxis()
# rotate the x axis label
plt.xticks(rotation=35, ha="right")
plt.xlabel("Image dataset 2")
plt.ylabel("Image dataset 1")
plt.title(f"FID score between image datasets \n (DINO-ViT-B14 {embed.shape[1]} embedding)")
saveallforms(join(GANembed_root, "summary"), "dataset_DINO_FID_ordmat")

# %%
df_mat_order
# Out:
# level_1                          massmem_objects  ecoset_val  places365_val  \
# level_0
# imagenet_valid                        696.841797  262.195801     550.910889
# massmem_objects                              NaN  548.663574    1041.005371
# ecoset_val                                   NaN         NaN     560.272705
# places365_val                                NaN         NaN            NaN
# DeePSim_4std                                 NaN         NaN            NaN
# BigGAN_trunc07                               NaN         NaN            NaN
# BigGAN_std_008                               NaN         NaN            NaN
# BigGAN_1000cls_BG_orig                       NaN         NaN            NaN
# BigGAN_1000cls_FC_invert                     NaN         NaN            NaN
# BigGAN_1000cls_BG_blur                       NaN         NaN            NaN
# resnet50_linf8_gradevol_fc                   NaN         NaN            NaN
# resnet50_linf8_gradevol_avgpool              NaN         NaN            NaN
# resnet50_linf8_gradevol_layer4               NaN         NaN            NaN
# resnet50_linf8_gradevol_layer3               NaN         NaN            NaN
# curvature_contour                            NaN         NaN            NaN
#
# level_1                          DeePSim_4std  BigGAN_trunc07  BigGAN_std_008  \
# level_0
# imagenet_valid                    1887.428833      279.197754      735.892090
# massmem_objects                   2021.300903      840.885986     1094.218750
# ecoset_val                        1887.175171      490.240723      873.324463
# places365_val                     1868.596680      741.518799     1063.103027
# DeePSim_4std                              NaN     1586.993652     1260.206543
# BigGAN_trunc07                            NaN             NaN      461.820312
# BigGAN_std_008                            NaN             NaN             NaN
# BigGAN_1000cls_BG_orig                    NaN             NaN             NaN
# BigGAN_1000cls_FC_invert                  NaN             NaN             NaN
# BigGAN_1000cls_BG_blur                    NaN             NaN             NaN
# resnet50_linf8_gradevol_fc                NaN             NaN             NaN
# resnet50_linf8_gradevol_avgpool           NaN             NaN             NaN
# resnet50_linf8_gradevol_layer4            NaN             NaN             NaN
# resnet50_linf8_gradevol_layer3            NaN             NaN             NaN
# curvature_contour                         NaN             NaN             NaN
#
# level_1                          BigGAN_1000cls_BG_orig  \
# level_0
# imagenet_valid                               297.412598
# massmem_objects                              844.395020
# ecoset_val                                   497.507080
# places365_val                                732.098145
# DeePSim_4std                                1525.922363
# BigGAN_trunc07                                25.160645
# BigGAN_std_008                               429.570557
# BigGAN_1000cls_BG_orig                              NaN
# BigGAN_1000cls_FC_invert                            NaN
# BigGAN_1000cls_BG_blur                              NaN
# resnet50_linf8_gradevol_fc                          NaN
# resnet50_linf8_gradevol_avgpool                     NaN
# resnet50_linf8_gradevol_layer4                      NaN
# resnet50_linf8_gradevol_layer3                      NaN
# curvature_contour                                   NaN
#
# level_1                          BigGAN_1000cls_FC_invert  \
# level_0
# imagenet_valid                                1354.536621
# massmem_objects                               1575.714844
# ecoset_val                                    1390.657715
# places365_val                                 1495.336426
# DeePSim_4std                                   537.739746
# BigGAN_trunc07                                1083.693359
# BigGAN_std_008                                 954.463135
# BigGAN_1000cls_BG_orig                        1027.760986
# BigGAN_1000cls_FC_invert                              NaN
# BigGAN_1000cls_BG_blur                                NaN
# resnet50_linf8_gradevol_fc                            NaN
# resnet50_linf8_gradevol_avgpool                       NaN
# resnet50_linf8_gradevol_layer4                        NaN
# resnet50_linf8_gradevol_layer3                        NaN
# curvature_contour                                     NaN
#
# level_1                          BigGAN_1000cls_BG_blur  \
# level_0
# imagenet_valid                               667.991211
# massmem_objects                             1086.766113
# ecoset_val                                   787.796143
# places365_val                                914.365479
# DeePSim_4std                                1519.701050
# BigGAN_trunc07                               536.240479
# BigGAN_std_008                               821.949219
# BigGAN_1000cls_BG_orig                       505.799561
# BigGAN_1000cls_FC_invert                     997.573730
# BigGAN_1000cls_BG_blur                              NaN
# resnet50_linf8_gradevol_fc                          NaN
# resnet50_linf8_gradevol_avgpool                     NaN
# resnet50_linf8_gradevol_layer4                      NaN
# resnet50_linf8_gradevol_layer3                      NaN
# curvature_contour                                   NaN
#
# level_1                          resnet50_linf8_gradevol_fc  \
# level_0
# imagenet_valid                                   667.214600
# massmem_objects                                 1059.830078
# ecoset_val                                       791.644531
# places365_val                                   1067.649658
# DeePSim_4std                                    1064.546753
# BigGAN_trunc07                                   477.082520
# BigGAN_std_008                                   654.643555
# BigGAN_1000cls_BG_orig                           456.098145
# BigGAN_1000cls_FC_invert                         631.211426
# BigGAN_1000cls_BG_blur                           696.384766
# resnet50_linf8_gradevol_fc                              NaN
# resnet50_linf8_gradevol_avgpool                         NaN
# resnet50_linf8_gradevol_layer4                          NaN
# resnet50_linf8_gradevol_layer3                          NaN
# curvature_contour                                       NaN
#
# level_1                          resnet50_linf8_gradevol_avgpool  \
# level_0
# imagenet_valid                                       1037.938965
# massmem_objects                                      1272.824219
# ecoset_val                                           1060.678223
# places365_val                                        1284.721191
# DeePSim_4std                                          661.200439
# BigGAN_trunc07                                        798.475342
# BigGAN_std_008                                        758.025391
# BigGAN_1000cls_BG_orig                                755.838623
# BigGAN_1000cls_FC_invert                              378.423828
# BigGAN_1000cls_BG_blur                                888.777344
# resnet50_linf8_gradevol_fc                            219.481689
# resnet50_linf8_gradevol_avgpool                              NaN
# resnet50_linf8_gradevol_layer4                               NaN
# resnet50_linf8_gradevol_layer3                               NaN
# curvature_contour                                            NaN
#
# level_1                          resnet50_linf8_gradevol_layer4  \
# level_0
# imagenet_valid                                      1082.672607
# massmem_objects                                     1327.054199
# ecoset_val                                          1114.763184
# places365_val                                       1294.204102
# DeePSim_4std                                         558.884521
# BigGAN_trunc07                                       842.984619
# BigGAN_std_008                                       732.346191
# BigGAN_1000cls_BG_orig                               794.861816
# BigGAN_1000cls_FC_invert                             307.426025
# BigGAN_1000cls_BG_blur                               882.465576
# resnet50_linf8_gradevol_fc                           294.045166
# resnet50_linf8_gradevol_avgpool                       94.252197
# resnet50_linf8_gradevol_layer4                              NaN
# resnet50_linf8_gradevol_layer3                              NaN
# curvature_contour                                           NaN
#
# level_1                          resnet50_linf8_gradevol_layer3  \
# level_0
# imagenet_valid                                      1396.473877
# massmem_objects                                     1576.696777
# ecoset_val                                          1415.879150
# places365_val                                       1520.208984
# DeePSim_4std                                         307.994385
# BigGAN_trunc07                                      1127.062500
# BigGAN_std_008                                       923.843506
# BigGAN_1000cls_BG_orig                              1069.744873
# BigGAN_1000cls_FC_invert                             285.022949
# BigGAN_1000cls_BG_blur                              1103.831299
# resnet50_linf8_gradevol_fc                           543.009521
# resnet50_linf8_gradevol_avgpool                      201.136963
# resnet50_linf8_gradevol_layer4                       131.525391
# resnet50_linf8_gradevol_layer3                              NaN
# curvature_contour                                           NaN
#
# level_1                          curvature_contour   pink_noise
# level_0
# imagenet_valid                         3269.055664  4143.382324
# massmem_objects                        2985.817871  4099.203613
# ecoset_val                             3182.982910  4110.698242
# places365_val                          3296.558838  4124.798340
# DeePSim_4std                           2826.672852  2972.873291
# BigGAN_trunc07                         3141.858643  4007.709229
# BigGAN_std_008                         3043.471680  3882.493408
# BigGAN_1000cls_BG_orig                 3116.501953  3978.052979
# BigGAN_1000cls_FC_invert               2718.253906  3192.793701
# BigGAN_1000cls_BG_blur                 2993.351807  3758.503418
# resnet50_linf8_gradevol_fc             3000.468262  3742.162598
# resnet50_linf8_gradevol_avgpool        2811.433838  3440.980713
# resnet50_linf8_gradevol_layer4         2782.428223  3379.075195
# resnet50_linf8_gradevol_layer3         2703.631592  3182.272461
# curvature_contour                              NaN  3733.411865

# %% [markdown]
# **Observation**
#
# * We can see by evolving from deeper layers of ResNet, the evolved image distribution deviates more and more from baseline distribution of DeePSim and approaches that of BigGAN / ImageNet.
# * BigGAN class sampling is the closest to ImageNet
# * Unit guided evolution makes the statistics closer to ImageNet / BigGAN class than direct inversion (by minimizing pixel L2 loss).

# %%
df_mat = df.reset_index().pivot(index="level_0", columns="level_1", values="FID_mean", )
# order the row and column
df_mat_order = df_mat.loc[dataset_strs[:-1]][dataset_strs[1:]]
plt.figure(figsize=(10, 10))
# plot the FID score as distance matrix
sns.heatmap(df_mat_order, cmap="YlGnBu", annot=True, fmt=".0f")
# inver the y axis
plt.gca().invert_yaxis()
# plt.gca().invert_xaxis()
# rotate the x axis label
plt.xticks(rotation=35, ha="right")
plt.xlabel("Image dataset 2")
plt.ylabel("Image dataset 1")
plt.title(f"Mean term in FID score between image datasets \n (DINO-ViT-B14 {embed.shape[1]} embedding)")
saveallforms(join(GANembed_root, "summary"), "dataset_DINO_FID_mean_ordmat")
df_mat_order.to_csv(join(GANembed_root, "summary", "dataset_DINO_FID_mean_ordmat.csv"))

# %%
df_mat = df.reset_index().pivot(index="level_0", columns="level_1", values="FID_cov", )
# order the row and column
df_mat_order = df_mat.loc[dataset_strs[:-1]][dataset_strs[1:]]
plt.figure(figsize=(10, 10))
# plot the FID score as distance matrix
sns.heatmap(df_mat_order, cmap="YlGnBu", annot=True, fmt=".0f")
# inver the y axis
plt.gca().invert_yaxis()
# plt.gca().invert_xaxis()
# rotate the x axis label
plt.xticks(rotation=35, ha="right")
plt.xlabel("Image dataset 2")
plt.ylabel("Image dataset 1")
plt.title(f"Cov term in FID score between image datasets \n (DINO-ViT-B14 {embed.shape[1]} embedding)")
saveallforms(join(GANembed_root, "summary"), "dataset_DINO_FID_cov_ordmat")
df_mat_order.to_csv(join(GANembed_root, "summary", "dataset_DINO_FID_cov_ordmat.csv"))

# %% [markdown]
# ## Distance of Evolved images to Reference distributions

# %%
# compute mahalanobis distance
def mahalanobis_sqdist(x, mean, eigvec, eigval, eigfloor=1e-5):
    x = x - mean[None, :]
    # rotate
    rot_x = x @ eigvec
    # scale
    return (rot_x ** 2 / torch.clamp(eigval[None, :], min=eigfloor)).sum(dim=1)

# %%
# plot functions to collect activation / distace according to gens. 
def compute_mean_var(x, gen_vec, var="std"):
    meanvec = []
    errvec = []
    for gen in range(gen_vec.min(), gen_vec.max()+1):
        meanvec.append(x[gen_vec==gen].mean())
        if var == "std":
            errvec.append(x[gen_vec==gen].std())
        elif var == "var":
            errvec.append(x[gen_vec==gen].var())
        elif var == "sem":
            errvec.append(x[gen_vec==gen].std() / np.sqrt((gen_vec==gen).sum()))
    return torch.tensor(meanvec), torch.tensor(errvec)

def plot_shaded_errorbar(x, y, color="b", label="", var="std", **kwargs):
    meanvec, errvec = compute_mean_var(y, x, var=var)
    plt.plot(np.unique(x), meanvec, color=color, label=label, **kwargs)
    plt.fill_between(np.unique(x), meanvec-errvec, meanvec+errvec, color=color, alpha=0.3)

# %%
def load_compute_eigen(dataset_str):
    if dataset_str == "imagenet_valid":
        embed = pkl.load(open(join(GANembed_dir, dataset_str+"_embedding.pkl"), "rb"))
    else:
        _, embed = pkl.load(open(join(GANembed_dir, dataset_str+"_embedding.pkl"), "rb"))
    embed = embed.cuda()
    cov = torch.cov(embed.T, )
    data_mean = embed.mean(dim=0)
    data_eigvals, data_eigvecs = torch.linalg.eigh(cov)
    data_eigvals = torch.flip(data_eigvals, dims=[0])
    data_eigvecs = torch.flip(data_eigvecs, dims=[1])
    return (data_mean, data_eigvals, data_eigvecs)

# %%
# FC_mean, FC_eigvals, FC_eigvecs = load_compute_eigen("DeePSim_4std")
# BG_mean, BG_eigvals, BG_eigvecs = load_compute_eigen("BigGAN_trunc07")
# BGRND_mean, BGRND_eigvals, BGRND_eigvecs = load_compute_eigen("BigGAN_std_008")
# IN_mean, IN_eigvals, IN_eigvecs = load_compute_eigen("imagenet_valid")
MH_eig_col = {}
for dataset_str in [
    "DeePSim_4std",
    "BigGAN_trunc07",
    "BigGAN_std_008",
    "imagenet_valid"
]:
    MH_eig_col[dataset_str] = load_compute_eigen(dataset_str)

# %%
import glob
embed_root = "/n/holylabs/LABS/kempner_fellows/Users/binxuwang/Projects/BigGAN_img_embedding"
Evol_embed_dir = join(embed_root, "dinov2_vitb14")
print(Evol_embed_dir)
# count number of files in the directory
num_files = len(glob.glob(join(Evol_embed_dir, "*")))
print(num_files)
# Out:
# /n/holylabs/LABS/kempner_fellows/Users/binxuwang/Projects/BigGAN_img_embedding/dinov2_vitb14
# 170

# %%
Evol_embed_dir
embed_dir
# Out:
# '/n/holylabs/LABS/kempner_fellows/Users/binxuwang/Projects/GAN_img_embedding/dinov2_vitb14'

# %%
os.path.exists(join(Evol_embed_dir, f"Exp{Expi}_embed_act_data.pkl"))
# Out:
# True

# %%
Evol_embed_dir
# Out:
# '/n/holylabs/LABS/kempner_fellows/Users/binxuwang/Projects/BigGAN_img_embedding/dinov2_vitb14'

# %%
# Expi = 184
for Expi in [50]:#tqdm(range(1, 190+1)):
    # if ~ os.path.exists(join(Evol_embed_dir, f"Exp{Expi}_embed_act_data.pkl")):
    #     continue
    Evol_data = pkl.load(open(join(Evol_embed_dir, f"Exp{Expi:03d}_embed_act_data.pkl"), "rb"))
    embeddings0 = Evol_data["embeddings0"]
    embeddings1 = Evol_data["embeddings1"]
    imgfps0 = Evol_data["imgfps0"]
    imgfps1 = Evol_data["imgfps1"]
    resp_mat0 = Evol_data["resp_mat0"]
    resp_mat1 = Evol_data["resp_mat1"]
    gen_vec0 = Evol_data["gen_vec0"]
    gen_vec1 = Evol_data["gen_vec1"]
    # MHdist_0 = mahalanobis_sqdist(embeddings0, IN_mean, IN_eigvec, IN_eigval, eigfloor=1e-2)
    # MHdist_1 = mahalanobis_sqdist(embeddings1, IN_mean, IN_eigvec, IN_eigval, eigfloor=1e-2)
    plt.figure()
    plot_shaded_errorbar(gen_vec0, resp_mat0[:, 0], color="b", label="thread 0", var="sem")
    plot_shaded_errorbar(gen_vec1, resp_mat1[:, 0], color="r", label="thread 1", var="sem")
    plt.title(f"Exp {Expi} mean response overall time window")
    plt.show()
    for dataset_str in MH_eig_col:
        data_mean, data_eigvals, data_eigvecs = MH_eig_col[dataset_str]
        MHdist_0 = mahalanobis_sqdist(embeddings0.cuda(), data_mean, data_eigvecs, data_eigvals, eigfloor=1e-3).cpu()
        MHdist_1 = mahalanobis_sqdist(embeddings1.cuda(), data_mean, data_eigvecs, data_eigvals, eigfloor=1e-3).cpu()
        # Evol_data[f"MHdist_{dataset_str}_0"] = MHdist_0
        # Evol_data[f"MHdist_{dataset_str}_1"] = MHdist_1
        plt.figure()
        plot_shaded_errorbar(gen_vec0, MHdist_0, color="b", label="thread 0", var="sem")
        plot_shaded_errorbar(gen_vec1, MHdist_1, color="r", label="thread 1", var="sem")
        plt.title(f"Exp {Expi} Mahalanobis distance to {dataset_str} embedding")
        plt.show()

# %%
Expi = 184
Evol_data = pkl.load(open(join(embed_dir, f"Exp{Expi}_embed_act_data.pkl"), "rb"))
embeddings0 = Evol_data["embeddings0"]
embeddings1 = Evol_data["embeddings1"]
imgfps0 = Evol_data["imgfps0"]
imgfps1 = Evol_data["imgfps1"]
resp_mat0 = Evol_data["resp_mat0"]
resp_mat1 = Evol_data["resp_mat1"]
gen_vec0 = Evol_data["gen_vec0"]
gen_vec1 = Evol_data["gen_vec1"]

# %%
MHdist_0 = mahalanobis_sqdist(embeddings0, IN_mean, IN_eigvec, IN_eigval, eigfloor=1e-2)
MHdist_1 = mahalanobis_sqdist(embeddings1, IN_mean, IN_eigvec, IN_eigval, eigfloor=1e-2)

# %%
# t test on the mahalanobis distance for gen 1 and last gen 
from scipy.stats import ttest_ind
print(ttest_ind(MHdist_0[gen_vec0<=3], MHdist_0[gen_vec0>=gen_vec0.max()-2]))
print(ttest_ind(MHdist_1[gen_vec1<=2], MHdist_1[gen_vec1>=gen_vec1.max()-1]))
# Out:
# TtestResult(statistic=-0.802136447658736, pvalue=0.4234761621072264, df=190.0)
# TtestResult(statistic=-5.35593181215439, pvalue=7.965883259394371e-07, df=80.0)

# %%
plt.figure()
plot_shaded_errorbar(gen_vec0, MHdist_0, color="b", label="thread 0", var="sem")
plot_shaded_errorbar(gen_vec1, MHdist_1, color="r", label="thread 1", var="sem")
plt.show()

plt.figure()
plot_shaded_errorbar(gen_vec0, resp_mat0[:, 0], color="b", label="thread 0", var="sem")
plot_shaded_errorbar(gen_vec1, resp_mat1[:, 0], color="r", label="thread 1", var="sem")
plt.show()

# %%
plt.plot(gen_vec0[:,],resp_mat0[:, 0], "o", alpha=0.5)
plt.plot(gen_vec1[:,],resp_mat1[:, 0], "o", alpha=0.5)
plt.xlabel("Generation")
plt.ylabel("Response (Hz)")
plt.title(f"Exp {Expi}")
plt.show()

plt.scatter(gen_vec0, MHdist_0, label="thread 1 DeepSim", marker=".", alpha=0.5)
plt.scatter(gen_vec1, MHdist_1, label="thread 2 BigGAN", marker=".", alpha=0.5)
plt.legend()
plt.xlabel("Generation")
plt.ylabel("Mahalanobis distance")
plt.title(f"Exp {Expi}")
plt.show()

# %% [markdown]
# ## Scratch zone

# %%
# Define the response time windows
# rsp_wdws += [range(strt, strt+25) for strt in range(0, 200, 25)]
# get image sequence and response in different time windows
# image paths: (n_images, )
# response: (n_images, n_time)
Expi = 155
Expi = 165
imgfps0, resp_mat0, gen_vec0 = load_img_resp_pairs_multiwindow(BFEStats, Expi,
                         "Evol", thread=0, stimdrive=stim_rootdir,
                        output_fmt="vec", rsp_wdws=rsp_wdws)
imgfps1, resp_mat1, gen_vec1 = load_img_resp_pairs_multiwindow(BFEStats, Expi,
                         "Evol", thread=1, stimdrive=stim_rootdir,
                         output_fmt="vec", rsp_wdws=rsp_wdws)

# %%
embeddings0, dataset0 = embed_imgs(imgfps0, embed_model, batch_size=100, size=224, device=device)
embeddings1, dataset1 = embed_imgs(imgfps1, embed_model, batch_size=100, size=224, device=device)

# %%
dataset = ImagePathDataset(imgfps0, transform=transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    normalizer,
]))
dataloader = DataLoader(dataset, batch_size=100, shuffle=False, num_workers=0)

# %%
embed_model = embed_model.cuda()
embed_model.eval()
embeddings = []
for batch, _ in tqdm(dataloader):
    batch = batch.cuda()
    with torch.no_grad():
        embed_vec = embed_model(batch)
    embeddings.append(embed_vec)
embeddings = torch.cat(embeddings, dim=0)

# %%
Expi = 184
embed_dir2 = join(embed_root, "dinov2_vitb14_local")
Evol_data2 = pkl.load(open(join(embed_dir2, f"Exp{Expi}_embed_act_data.pkl"), "rb"))
Evol_data = pkl.load(open(join(embed_dir, f"Exp{Expi}_embed_act_data.pkl"), "rb"))
# compare embeddings
assert torch.allclose(Evol_data["embeddings0"], Evol_data2["embeddings0"], atol=1e-3, rtol=1e-3)
assert torch.allclose(Evol_data["embeddings1"], Evol_data2["embeddings1"], atol=1e-3, rtol=1e-3)
# Out:
# ---------------------------------------------------------------------------
#
# AssertionError                            Traceback (most recent call last)
#
# Cell In[132], line 6
#
#       4 Evol_data = pkl.load(open(join(embed_dir, f"Exp{Expi}_embed_act_data.pkl"), "rb"))
#
#       5 # compare embeddings
#
# ----> 6 assert torch.allclose(Evol_data["embeddings0"], Evol_data2["embeddings0"], atol=1e-3, rtol=1e-3)
#
#       7 assert torch.allclose(Evol_data["embeddings1"], Evol_data2["embeddings1"], atol=1e-3, rtol=1e-3)
#
#
#
# AssertionError:

# %%
Evol_data["embeddings0"].abs().sum()
# Out:
# tensor(1617812.6250)

# %%
(Evol_data2["embeddings0"] - Evol_data["embeddings0"]).abs().sum()
# Out:
# tensor(2570.2437)

# %%
Evol_data["embeddings0"]
# Out:
# tensor([[ 0.1951,  0.4970,  1.3513,  ..., -0.0663,  0.2268, -1.2306],
#         [-0.7044, -1.0375,  1.1795,  ..., -2.3465, -2.0538, -1.3802],
#         [-0.4620,  0.0822,  0.5605,  ..., -1.1973,  1.8351, -2.0165],
#         ...,
#         [ 2.2823,  0.7341,  1.8795,  ...,  0.2762,  0.5284,  0.2757],
#         [ 1.9710,  0.8025,  1.4064,  ...,  0.0788,  0.7820,  0.7175],
#         [ 2.6020,  0.1914,  2.2508,  ..., -0.1077, -1.4906,  0.9322]])
